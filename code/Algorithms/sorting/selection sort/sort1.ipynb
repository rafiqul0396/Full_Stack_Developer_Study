# %% [markdown]
# I believe you meant "selection sort," which is a simple sorting algorithm. Selection sort divides the input list into two parts: the sorted part, which starts as an empty list, and the unsorted part, which contains the entire input list. The algorithm repeatedly finds the smallest (or largest, depending on the sorting order) element from the unsorted part and moves it to the end of the sorted part. This process is repeated until the entire list is sorted.
#
# Here's how selection sort works:
#
# - Find the minimum (or maximum) element in the unsorted part of the list.
# - Swap this element with the first element in the unsorted part of the list.
# - Expand the sorted part of the list by one element and shrink the unsorted part by one element.
# - Repeat steps 1 to 3 until the unsorted part becomes empty.
# - The time complexity of selection sort is O(n^2) in the worst case, where n is the number of elements in the list. It is not very efficient for large lists but can be useful for small lists or as an educational tool to understand sorting algorithms.

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_index = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j

        # Swap the found minimum element with the first element of the unsorted part
        arr[i], arr[min_index] = arr[min_index], arr[i]

    return arr

# Example usage:
input_list = [64, 34, 25, 12, 22, 11, 90]
sorted_list = selection_sort(input_list)
print(sorted_list)  # Output: [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# ##### Bubble Sort
#
# -

# %%
## swap with adjecent element in the array 
# Optimized Python program for implementation of Bubble Sort


def bubbleSort(arr):
	n = len(arr)
	
	# Traverse through all array elements
	for i in range(n):
		swapped = False

		# Last i elements are already in place
		for j in range(0, n-i-1):

			# Traverse the array from 0 to n-i-1
			# Swap if the element found is greater
			# than the next element
			if arr[j] > arr[j+1]:
				arr[j], arr[j+1] = arr[j+1], arr[j]
				swapped = True
		if (swapped == False):
			break


# Driver code to test above
if __name__ == "__main__":
	arr = [64, 34, 25, 12, 22, 11, 90]

	bubbleSort(arr)

	print("Sorted array:")
	for i in range(len(arr)):
		print("%d" % arr[i], end=" ")

# %%
def sortColors(nums) -> None:

        n=len(nums)
        lst=[1]*n
        leftptr=0
        rightptr=n-1

        for i in range(n):
            if nums[i]==0:
                lst[leftptr]=0
                leftptr+=1
            elif nums[i]==2:
                lst[rightptr]=2
                rightptr-=1
        return lst
if __name__=='__main__':
    nums=[2,0,2,1,1,0]
    print(sortColors(nums))
# Out:
# [0, 0, 1, 1, 2, 2]

# %%
a=2
b=3
a,b=b,a

# %%
a
# Out:
# 3

# %%
lst=[[1,3],[2,4],[5,7],[6,8],[5,9]]
lst.sort(key=lambda x:x[0])

# %%
lst
# Out:
# [[1, 3], [2, 4], [5, 7], [5, 9], [6, 8]]

# %%
# !pip install seaborn
# Out:
# ...
#      -------------------------------------- 293.3/293.3 kB 6.0 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 4, 1, 6, 8]

# Using Matplotlib to create a line plot
plt.plot(x, y, label='Data')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Simple Line Plot')
plt.legend()
plt.show()

# Using Seaborn to create a line plot
sns.lineplot(x=x, y=y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Simple Line Plot with Seaborn')
plt.show()
