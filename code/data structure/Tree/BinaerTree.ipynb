# %%
#Binary Tree
#Binary Tree is a tree data structure in which each node has at most two children, which are referred to as the left child and the right child.
#Binary Tree is a special case of a tree data structure in which each node can have at most two children.
#Binary Tree is a special case of a tree data structure in which each node can have at most two children.


#construct a binary tree

class Node:
    def __init__(self,data):
        self.left=None
        self.right=None
        self.data=data
    def insert(self,data):
        if self.data:
            if data<self.data:
                if self.left is None:
                    self.left=Node(data)
                else:
                    self.left.insert(data)
            elif data>self.data:
                if self.right is None:
                    self.right=Node(data)
                else:
                    self.right.insert(data)
        else:
            self.data=data
    def PrintTree(self):
        if self.left:
            self.left.PrintTree()
        print(self.data)
        if self.right:
            self.right.PrintTree()
    def search(self,data):
        if data<self.data:
            if self.left is None:
                print("Not found")
            else:
                self.left.search(data)
        elif data>self.data:
            if self.right is None:
                print("Not found")
            else:
                self.right.search(data)
        else:
            print("Found")
#driver code
if __name__ == "__main__":
    root=Node(12)
    root.insert(6)
    root.insert(14)
    root.insert(3)
    root.PrintTree()
    root.search(14)
# Out:
# 3
# 6
# 12
# 14
# Found

# %%
#Maximum Depth of Binary Tree
#Given a binary tree, find its maximum depth.
#The maximum depth is the number of nodes along the longest path from the root node down to the farthest leaf node.
#Note: A leaf is a node with no children.
#Example:
#Given binary tree [3,9,20,null,null,15,7],
#    3
#   / \
#  9  20
#    /  \
#   15   7
#return its depth = 3.
#Definition for a binary tree node.
class TreeNode:
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
class Solution:
    def maxDepth(self, root: TreeNode) -> int:
        if root is None:
            return 0
        else:
            left_height=self.maxDepth(root.left)
            right_height=self.maxDepth(root.right)
            return max(left_height,right_height)+1
#driver code
if __name__ == "__main__":
    root=TreeNode(3)
    root.left=TreeNode(9)
    root.right=TreeNode(20)
    root.right.left=TreeNode(15)
    root.right.right=TreeNode(7)
    print(Solution().maxDepth(root))
# Out:
# 3

# %%
#Minimum Depth of Binary Tree
#Given a binary tree, find its minimum depth.
#The minimum depth is the number of nodes along the shortest path from the root node down to the nearest leaf node.
#Note: A leaf is a node with no children.
#Example:
#Given binary tree [3,9,20,null,null,15,7],
#    3
#   / \
#  9  20
#    /  \
#   15   7
#return its minimum depth = 2.
#Definition for a binary tree node.

def minimum_depth(root):
    if root is None:
        return 0
    if root.left is None and root.right is None:
        return 1
    if root.left is None:
        return minimum_depth(root.right)+1
    if root.right is None:
        return minimum_depth(root.left)+1
    return min(minimum_depth(root.left),minimum_depth(root.right))+1
#driver code
if __name__ == "__main__":
    root=TreeNode(3)
    root.left=TreeNode(9)
    root.right=TreeNode(20)
    root.right.left=TreeNode(15)
    root.right.right=TreeNode(7)
    print(minimum_depth(root))
# Out:
# 2

# %%
#Symmetric Tree
#Given a binary tree, check whether it is a mirror of itself (ie, symmetric around its center).
#For example, this binary tree [1,2,2,3,4,4,3] is symmetric:
#    1
#   / \
#  2   2
# / \ / \
#3  4 4  3
#But the following [1,2,2,null,3,null,3] is not:
#    1
#   / \
#  2   2
#   \   \
#   3    3
#Note:
#Bonus points if you could solve it both recursively and iteratively.
#Definition for a binary tree node.


def isSymmetric(root):
    if root is None:
        return True
    def isMirror(left,right):
        if left is None and right is None:
            return True
        if left is None or right is None:
            return False
        return (left.val==right.val) and isMirror(left.left,right.right) and isMirror(left.right,right.left)
    return isMirror(root.left,root.right)

#driver code
if __name__ == "__main__":
    root=TreeNode(1)
    root.left=TreeNode(2)
    root.right=TreeNode(2)
    root.left.left=TreeNode(3)
    root.left.right=TreeNode(4)
    root.right.left=TreeNode(4)
    root.right.right=TreeNode(3)
    print(isSymmetric(root))
# Out:
# True

# %%
#same tree
#Given two binary trees, write a function to check if they are the same or not.
#Two binary trees are considered the same if they are structurally identical and the nodes have the same value.
#Example 1:
#Input:     1         1
#          / \       / \
#         2   3     2   3
#        [1,2,3],   [1,2,3]
#Output: true

#Example 2:
#Input:     1         1
#          /           \
#         2             2
#        [1,2],     [1,null,2]
#Output: false


#Example 3:
#Input:     1         1
#          / \       / \
#         2   1     1   2
#        [1,2,1],   [1,1,2]
#Output: false
#Definition for a binary tree node.


def isSameTree(p, q):
    if p is None and q is None:
        return True
    if p is None or q is None:
        return False
    return (p.val==q.val) and isSameTree(p.left,q.left) and isSameTree(p.right,q.right)

#driver code
if __name__ == "__main__":
    p=TreeNode(1)
    p.left=TreeNode(2)
    p.right=TreeNode(1)
    q=TreeNode(1)
    q.left=TreeNode(1)
    q.right=TreeNode(2)
    print(isSameTree(p,q))
# Out:
# False

# %%
#Invert Binary Tree
#Invert a binary tree.
#Example:
#Input:
#     4
#   /   \
#  2     7
# / \   / \
#1   3 6   9
#Output:
#     4
#   /   \
#  7     2
# / \   / \
#9   6 3   1
#Trivia:
#This problem was inspired by this original tweet by Max Howell:

#Google: 90% of our engineers use the software you wrote (Homebrew),
#but you can’t invert a binary tree on a whiteboard so f*** off.


def invertTree(root):
    if root is None:
        return None
    root.left,root.right=root.right,root.left
    invertTree(root.left)
    invertTree(root.right)
    return root

#driver code
if __name__ == "__main__":
    root=TreeNode(4)
    root.left=TreeNode(2)
    root.right=TreeNode(7)
    root.left.left=TreeNode(1)
    root.left.right=TreeNode(3)
    root.right.left=TreeNode(6)
    root.right.right=TreeNode(9)
    print(invertTree(root))

# %%
#Traversal  of Binary Tree
#Given a binary tree, return the preorder traversal of its nodes' values.
#Example:
#Input: [1,null,2,3]
#   1
#    \
#     2
#    /
#   3
#Output: [1,2,3]
#Follow up: Recursive solution is trivial, could you do it iteratively?
#Definition for a binary tree node.



def preorderTraversal(root):
    if root is None:
        return []
    return [root.val]+preorderTraversal(root.left)+preorderTraversal(root.right)


#driver code
if __name__ == "__main__":
    root=TreeNode(1)
    root.right=TreeNode(2)
    root.right.left=TreeNode(3)
    print(preorderTraversal(root))
# Out:
# [1, 2, 3]

# %%
#Given a binary tree, return the inorder traversal of its nodes' values.
#Example:
#Input: [1,null,2,3]
#   1
#    \
#     2
#    /
#   3
#Output: [1,3,2]
#Follow up: Recursive solution is trivial, could you do it iteratively?
#Definition for a binary tree node.


def inorderTraversal(root):
    if root is None:
        return []
    return inorderTraversal(root.left)+[root.val]+inorderTraversal(root.right)

#driver code
if __name__ == "__main__":
    root=TreeNode(1)
    root.right=TreeNode(2)
    root.right.left=TreeNode(3)
    print(inorderTraversal(root))
# Out:
# [1, 3, 2]

# %%
#Given a binary tree, return the postorder traversal of its nodes' values.
#Example:
#Input: [1,null,2,3]
#   1
#    \
#     2
#    /
#   3
#Output: [3,2,1]
#Follow up: Recursive solution is trivial, could you do it iteratively?
#Definition for a binary tree node.


def postorderTraversal(root):
    if root is None:
        return []
    return postorderTraversal(root.left)+postorderTraversal(root.right)+[root.val]


#driver code
if __name__ == "__main__":
    root=TreeNode(1)
    root.right=TreeNode(2)
    root.right.left=TreeNode(3)
    print(postorderTraversal(root))
# Out:
# [3, 2, 1]

# %%
#Binary Tree Level Order Traversal
#Given a binary tree, return the level order traversal of its nodes' values. (ie, from left to right, level by level).
#For example:
#Given binary tree [3,9,20,null,null,15,7],
#    3
#   / \
#  9  20
#    /  \
#   15   7
#return its level order traversal as:

#[
#  [3],
#  [9,20],
#  [15,7]
#]
#Definition for a binary tree node.



def levelOrder(root):
    if root is None:
        return []
    queue=[root]
    result=[]
    while queue:
        level=[]
        for i in range(len(queue)):
            node=queue.pop(0)
            level.append(node.val)
            if node.left:
                queue.append(node.left)
            if node.right:
                queue.append(node.right)
        result.append(level)
    return result

#driver code
if __name__ == "__main__":
    root=TreeNode(3)
    root.left=TreeNode(9)
    root.right=TreeNode(20)
    root.right.left=TreeNode(15)
    root.right.right=TreeNode(7)
    print(levelOrder(root))
# Out:
# [[3], [9, 20], [15, 7]]

# %%
#Binary Tree Zigzag Level Order Traversal
#Given a binary tree, return the zigzag level order traversal of its nodes' values. (ie, from left to right, then right to left for the next level and alternate between).
#For example:
#Given binary tree [3,9,20,null,null,15,7],
#    3
#   / \
#  9  20
#    /  \
#   15   7
#return its zigzag level order traversal as:
#[
#  [3],
#  [20,9],
#  [15,7]
#]
#Definition for a binary tree node.



def zigzagLevelOrder(root):
    if root is None:
        return []
    queue=[root]
    result=[]
    flag=0
    while queue:
        level=[]
        for i in range(len(queue)):
            node=queue.pop(0)
            level.append(node.val)
            if node.left:
                queue.append(node.left)
            if node.right:
                queue.append(node.right)
        if flag==0:
            result.append(level)
            flag=1
        else:
            result.append(level[::-1])
            flag=0
    return result


#driver code
if __name__ == "__main__":
    root=TreeNode(3)
    root.left=TreeNode(9)
    root.right=TreeNode(20)
    root.right.left=TreeNode(15)
    root.right.right=TreeNode(7)
    print(zigzagLevelOrder(root))
# Out:
# [[3], [20, 9], [15, 7]]

# %%
#Binary Tree Maximum Path Sum
#Given a non-empty binary tree, find the maximum path sum.
#For this problem, a path is defined as any node sequence from some starting node to any node in the tree along the parent-child connections. The path must contain at least one node and does not need to go through the root.
#Example 1:
#Input: [1,2,3]
#       1
#      / \
#     2   3
#Output: 6
#Example 2:
#Input: [-10,9,20,null,null,15,7]
#   -10
#   / \
#  9  20
#    /  \
#   15   7
#Output: 42
#Definition for a binary tree node.

def maxPathSum(root):
    if root is None:
        return 0
    left=maxPathSum(root.left)
    right=maxPathSum(root.right)
    return max(left+right+root.val,left,right)
def findPathSum(root):
    if root is None:
        return 0
    left=findPathSum(root.left)
    right=findPathSum(root.right)
    return max(0,root.val+max(left,right))

def pathsumII(root,sum):
    if root is None:
        return []
    if root.left is None and root.right is None and root.val==sum:
        return [[root.val]]
    left=pathsumII(root.left,sum-root.val)
    right=pathsumII(root.right,sum-root.val)
    return [[root.val]+i for i in left+right]
def pathsumIII(root,sum):
    if root is None:
        return 0
    return pathsumII(root,sum)+pathsumIII(root.left,sum)+pathsumIII(root.right,sum)

def sumRootLeaf(root):
    if root is None:
        return 0
    if root.left is None and root.right is None:
        return root.val
    left=sumRootLeaf(root.left)
    right=sumRootLeaf(root.right)
    return left*10+right+root.val

def maxRootLeaf(root):
    if root is None:
        return 0
    if root.left is None and root.right is None:
        return root.val
    left=maxRootLeaf(root.left)
    right=maxRootLeaf(root.right)
    return max(left,right)+root.val

def minRootLeaf(root):
    if root is None:
        return 0
    if root.left is None and root.right is None:
        return root.val
    left=minRootLeaf(root.left)
    right=minRootLeaf(root.right)
    return min(left,right)+root.val

def sumNumbers(root):
    if root is None:
        return 0
    if root.left is None and root.right is None:
        return root.val
    left=sumNumbers(root.left)
    right=sumNumbers(root.right)
    return left*10+right+root.val*2


def maxLeaf(root):
    if root is None:
        return 0
    if root.left is None and root.right is None:
        return root.val
    left=maxLeaf(root.left)
    right=maxLeaf(root.right)
    return max(left,right)
def leafNode(root):
    if root is None:
        return 0
    if root.left is None and root.right is None:
        return 1
    left=leafNode(root.left)
    right=leafNode(root.right)
    return left+right

def sumleafNode(root):
    if root is None:
        return 0
    if root.left is None and root.right is None:
        return root.val
    left=sumleafNode(root.left)
    right=sumleafNode(root.right)
    return left+right
def maxandminleaf(root):
    if root is None:
        return 0
    if root.left is None and root.right is None:
        return root.val
    left=maxandminleaf(root.left)
    right=maxandminleaf(root.right)
    return [max(left,right),min(left,right)]

def search(root,target):
    if root is None:
        return False
    if root.val==target:
        return True
    left=search(root.left,target)
    right=search(root.right,target)
    return left or right

def Largest(root):
    if root is None:
        return 0
    if root.left is None and root.right is None:
        return root.val
    left=secondLargest(root.left)
    right=secondLargest(root.right)
    return max(left,right)
def MinNode(root):
    if root is None:
        return 0
    if root.left is None and root.right is None:
        return root.val
    left=MinNode(root.left)
    right=MinNode(root.right)
    return min(left,right)
def secondLargest(root):
    if root is None:
        return 0
    if root.left is None and root.right is None:
        return root.val
    left=Largest(root.left)
    right=Largest(root.right)
    if left>right:
        return max(left,MinNode(root.right))
    else:
        return max(right,MinNode(root.left))
def MinNode(root):
    if root is None:
        return 0
    if root.left is None and root.right is None:
        return root.val
    left=MinNode(root.left)
    right=MinNode(root.right)
    return min(left,right)

def distinctNode(root):
    if root is None:
        return 0
    if root.left is None and root.right is None:
        return 1
    left=distinctNode(root.left)
    right=distinctNode(root.right)
    return left+right


#driver code

if __name__ == "__main__":
    root=TreeNode(1)
    root.left=TreeNode(2)
    root.right=TreeNode(3)
    #root.left.left=TreeNode(2)
    print(findPathSum(root))
    print(maxPathSum(root))
    print(pathsumII(root,3))
    #print(pathsumIII(root,3))
    print(sumRootLeaf(root))
    print(maxRootLeaf(root))
    print(minRootLeaf(root))
    print(sumNumbers(root))
    print(maxLeaf(root))
    print(leafNode(root))
    print(sumleafNode(root))
    print(maxandminleaf(root))
    print(search(root,3))
    print(secondLargest(root))
    print(secondLargest(root))
    print(distinctNode(root))
# Out:
# 4
# 6
# [[1, 2]]
# 24
# 4
# 3
# 25
# 3
# 2
# 5
# [3, 2]
# True
# 3
# 3
# 2

# %%
#construct tree from inorder and preorder
#example
#inorder=[9,3,15,20,7]
#preorder=[3,9,20,15,7]
#output=3,9,20,null,null,15,7

class TreeNode:
    def __init__(self,val):
        self.val=val
        self.left=None
        self.right=None
    
def buildTree(inorder,preorder):
        if len(inorder)==0:
            return None
        root=TreeNode(preorder[0])
        i=inorder.index(preorder[0])
        root.left=buildTree(inorder[:i],preorder[1:i+1])
        root.right=buildTree(inorder[i+1:],preorder[i+1:])
        return root

def buildTree2(inorder,postorder):
        if len(inorder)==0:
            return None
        root=TreeNode(postorder[-1])
        i=inorder.index(postorder[-1])
        root.left=buildTree(inorder[:i],postorder[:i])
        root.right=buildTree(inorder[i+1:],postorder[i:-1])
        return root

    

#driver code
if __name__ == "__main__":
    inorder=[9,3,15,20,7]
    preorder=[3,9,20,15,7]
    root=buildTree(inorder,preorder)

    print(root.val)
    print(root.left.val)
    print(root.right.val)
    print(root.right.left.val)
    print(root.right.right.val)
    postorder=[9,15,7,20,3]
    root2=buildTree2(inorder,postorder)
    print(root2.val)
    print(root2.left.val)
    print(root2.right.val)
    print(root2.right.left.val)
    print(root2.right.right.val)
# Out:
# 3
# 9
# 20
# 15
# 7
# 3
# 9
# 15
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 49
#      47 print(root2.left.val)
#      48 print(root2.right.val)
# ---> 49 print(root2.right.left.val)
#      50 print(root2.right.right.val)
#
# AttributeError: 'NoneType' object has no attribute 'val'

# %%
#construct tree from inorder and postorder
#example
#inorder=[9,3,15,20,7]
#postorder=[9,15,7,20,3]
#output=3,9,20,null,null,15,7



#construct tree from preorder and postorder
#example
#preorder=[1,2,4,5,3,6,7]

#postorder=[4,5,2,6,7,3,1]
#output=1,2,3,4,5,6,7

class TreeNode:
    def __init__(self,val):
        self.val=val
        self.left=None
        self.right=None

def buildTree(preorder,postorder):
    if len(preorder)==0:
        return None
    root=TreeNode(preorder[0])
    if len(preorder)==1:
        return root
    i=postorder.index(preorder[1])+1
    root.left=buildTree(preorder[1:i+1],postorder[:i])
    root.right=buildTree(preorder[i+1:],postorder[i:-1])
    return root

#driver code
if __name__ == "__main__":
    preorder=[1,2,4,5,3,6,7]
    postorder=[4,5,2,6,7,3,1]
    root=buildTree(preorder,postorder)
    print(root.val)
    print(root.left.val)
    print(root.right.val)
    print(root.left.left.val)
    print(root.left.right.val)
    print(root.right.left.val)
    print(root.right.right.val)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
#construct tree from preorder and postorder
#example
#preorder=[1,2,4,5,3,6,7]


#postorder=[4,5,2,6,7,3,1]
#output=1,2,3,4,5,6,7

#construct tree from preorder and postorder
#example
#preorder=[1,2,4,5,3,6,7]

#postorder=[4,5,2,6,7,3,1]
#output=1,2,3,4,5,6,7

class TreeNode:

    def __init__(self,val):
        self.val=val
        self.left=None
        self.right=None 

def buildTree(preorder,postorder):

    if len(preorder)==0:
        return None
    root=TreeNode(preorder[0])
    if len(preorder)==1:
        return root
    i=postorder.index(preorder[1])+1
    root.left=buildTree(preorder[1:i+1],postorder[:i])
    root.right=buildTree(preorder[i+1:],postorder[i:-1])
    return root


#driver code

if __name__ == "__main__":
    preorder=[1,2,4,5,3,6,7]
    postorder=[4,5,2,6,7,3,1]
    root=buildTree(preorder,postorder)
    print(root.val)
    print(root.left.val)
    print(root.right.val)
    print(root.left.left.val)
    print(root.left.right.val)
    print(root.right.left.val)
    print(root.right.right.val)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
#Binary  Tree Right Side View
#example
#input=[1,2,3,null,5,null,4]
#output=[1,3,4]

class TreeNode:
    def __init__(self,val):
        self.val=val
        self.left=None
        self.right=None
    
def rightSideView(root):
    if root==None:
        return []
    queue=[]
    result=[]
    queue.append(root)
    while len(queue)>0:
        size=len(queue)
        for i in range(size):
            node=queue.pop(0)
            if i==size-1:
                result.append(node.val)
            if node.left!=None:
                queue.append(node.left)
            if node.right!=None:
                queue.append(node.right)
    return result

#driver code
if __name__ == "__main__":
    root=TreeNode(1)
    root.left=TreeNode(2)
    root.right=TreeNode(3)
    root.left.right=TreeNode(5)
    root.right.right=TreeNode(4)
    print(rightSideView(root))
# Out:
# [1, 3, 4]

# %%
#Binary  Tree left side view
#example
#input=[1,2,3,null,5,null,4]
#output=[1,2,5]

class TreeNode:
    def __init__(self,val):
        self.val=val
        self.left=None
        self.right=None


def leftSideView(root):
    if root==None:
        return []
    queue=[]
    result=[]
    queue.append(root)
    while len(queue)>0:
        size=len(queue)
        for i in range(size):
            node=queue.pop(0)
            if i==0:
                result.append(node.val)
            if node.left!=None:
                queue.append(node.left)
            if node.right!=None:
                queue.append(node.right)
    return result


#driver code
if __name__ == "__main__":
    root=TreeNode(1)
    root.left=TreeNode(2)
    root.right=TreeNode(3)
    root.left.right=TreeNode(5)
    root.right.right=TreeNode(4)
    print(leftSideView(root))
# Out:
# [1, 2, 5]

# %%
#Binary  Tree top side view
#
#example
#input=[1,2,3,null,5,null,4]
#output=[1,2,3,4]


class TreeNode:
    def __init__(self,val):
        self.val=val
        self.left=None
        self.right=None

def topSideView(root):
    if root==None:
        return []
    queue=[]
    result=[]
    queue.append(root)
    while len(queue)>0:
        size=len(queue)
        for i in range(size):
            node=queue.pop(0)
            if i==0:
                result.append(node.val)
            if node.left!=None:
                queue.append(node.left)
            if node.right!=None:
                queue.append(node.right)
    return result

#driver code
if __name__ == "__main__":
    root=TreeNode(1)
    root.left=TreeNode(2)
    root.right=TreeNode(3)
    root.left.right=TreeNode(5)
    root.right.right=TreeNode(4)
    print(topSideView(root))
# Out:
# [1, 2, 5]

# %%
class Node:
    def __init__(self, val=None, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def top_view(root):
    if not root:
        return []
    
    # dictionary to store nodes at each horizontal distance
    hd_map = {}
    
    # queue for level order traversal
    queue = [(root, 0)]
    
    while queue:
        node, hd = queue.pop(0)
        
        # add current node to hd_map if not already present
        if hd not in hd_map:
            hd_map[hd] = node.val
        
        # enqueue left child with horizontal distance hd-1
        if node.left:
            queue.append((node.left, hd-1))
        
        # enqueue right child with horizontal distance hd+1
        if node.right:
            queue.append((node.right, hd+1))
    
    # print nodes from hd_map in ascending order of hd values
    min_hd, max_hd = min(hd_map.keys()), max(hd_map.keys())
    res = [hd_map[i] for i in range(min_hd, max_hd+1)]
    return res


#driver code
if __name__ == "__main__":
    root=Node(1)
    root.left=Node(2)
    root.right=Node(3)
    root.left.right=Node(5)
    root.right.right=Node(4)
    print(top_view(root))
# Out:
# [2, 1, 3, 4]

# %%
#Binary  Tree bottom side view
#
#example
#input=[1,2,3,null,5,null,4]
#output=[2,5,4]


class TreeNode:
    def __init__(self,val):
        self.val=val
        self.left=None
        self.right=None

def bottomSideView(root):
# Out:
#   Cell In[60], line 14
#     def bottomSideView(root):
#                              ^
# SyntaxError: incomplete input

# %%
class Node:
    def __init__(self, val=None, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right




def bottom_view(root):
    if not root:
        return []
    
    # dictionary to store nodes at each horizontal distance
    hd_map = {}
    
    # queue for level order traversal
    queue = [(root, 0)]
    
    while queue:
        node, hd = queue.pop(0)
        
        # update hd_map with current node
        hd_map[hd] = node.val
        
        # enqueue left child with horizontal distance hd-1
        if node.left:
            queue.append((node.left, hd-1))
        
        # enqueue right child with horizontal distance hd+1
        if node.right:
            queue.append((node.right, hd+1))
    
    # print last node from hd_map for each horizontal distance
    min_hd, max_hd = min(hd_map.keys()), max(hd_map.keys())
    res = [hd_map[i] for i in range(min_hd, max_hd+1)]
    return res


#driver code
if __name__ == "__main__":
    root=Node(1)
    root.left=Node(2)
    root.right=Node(3)
    root.left.right=Node(5)
    root.right.right=Node(4)
    print(bottom_view(root))
# Out:
# [2, 5, 3, 4]

# %%
# vertical order traversal of binary tree
#example
#input=[1,2,3,4,5,6,7]
#output=[[4],[2],[1,5,6],[3],[7]]

class TreeNode:
    def __init__(self,val):
        self.val=val
        self.left=None
        self.right=None
    


def verticalOrder(root):
    ...

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def verticalOrder(root: TreeNode):
    # Base case
    if not root:
        return []

    # Dictionary to store nodes at each vertical distance
    nodes_dict = {}

    # DFS function to traverse the tree and add nodes to dictionary
    def dfs(node, col, row):
        if node:
            nodes_dict[col] = nodes_dict.get(col, []) + [(row, node.val)]
            dfs(node.left, col-1, row+1)
            dfs(node.right, col+1, row+1)

    # Start DFS traversal from root
    dfs(root, 0, 0)

    # Sort the keys (vertical distances) of the dictionary
    cols = sorted(nodes_dict.keys())

    # Create result list of nodes in each column
    res = []
    for col in cols:
        nodes = [val[1] for val in sorted(nodes_dict[col])]
        res.append(nodes)

    return res


#driver code
if __name__ == "__main__":
    root=TreeNode(1)
    root.left=TreeNode(2)
    root.right=TreeNode(3)
    root.left.left=TreeNode(4)
    root.left.right=TreeNode(5)
    root.right.left=TreeNode(6)
    root.right.right=TreeNode(7)
    print(verticalOrder(root))
# Out:
# [[4], [2], [1, 5, 6], [3], [7]]
